# %% [markdown]
# <a href="https://colab.research.google.com/github/dj202410201-afk/github_noob/blob/main/%EA%B0%95%EC%83%81%EC%9C%A4_1%EC%A3%BC%EC%B0%A8_%EA%B9%83%ED%97%88%EB%B8%8C_%EC%A0%80%EC%9E%A5%EC%86%8C%ED%99%9C%EC%9A%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Printing Multiplication Table

x = int(input("Write the first number : "))

for i in range(1, 10):
  print(f"{x} times {i} is {x*i}")
# Out:
# Write the first number : 00000000000009
# 9 times 1 is 9
# 9 times 2 is 18
# 9 times 3 is 27
# 9 times 4 is 36
# 9 times 5 is 45
# 9 times 6 is 54
# 9 times 7 is 63
# 9 times 8 is 72
# 9 times 9 is 81
