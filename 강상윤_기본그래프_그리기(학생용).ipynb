# %% [markdown]
# <a href="https://colab.research.google.com/github/dj202410201-afk/2026_data_science_student/blob/main/%EA%B0%95%EC%83%81%EC%9C%A4_%EA%B8%B0%EB%B3%B8%EA%B7%B8%EB%9E%98%ED%94%84_%EA%B7%B8%EB%A6%AC%EA%B8%B0(%ED%95%99%EC%83%9D%EC%9A%A9).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1️⃣matplotlib라이브러리
#
# * 파이썬에서 2D형태의 그래프, 이미지 등을 그릴 때 사용하는 것
# * 실제 과학 컴퓨팅 연구분야나 인공지능 연구분야에서 많이 활용됨
#
# * 아래 실습에서는 matplotlib 라이브러리 안에 pyplot 모듈을 주로 사용할 것!

# %% [markdown]
# ##🌟모듈이란?
# 여러 클래스, ______, _______를 가지고 있는 파이썬 파일(.py)
#
#
# 예) 모듈의 종류 : ________, __________, _________, _________ 등

# %%
#라이브러리 불러오기
import matplotlib.pyplot

# %%
#별명(alias)사용하기
import matplotlib.pyplot as plt

# %% [markdown]
# # 2️⃣기본 그래프 그리기

# %% [markdown]
# ##🔎plot()함수
# * 직선 또는 꺾은선 형태의 그래프를 그릴 때 사용할 수 있는 명령어

# %% [markdown]
# ##첫번째 그래프

# %%
#리스트[10,20,30,40] 값을 가지는 그래프를 그리는 코드를 작성하시오.

import matplotlib.pyplot as plt

temp = []
for i in range(1000):
  temp.append(i)

plt.plot(temp)  #리스트의 값이 y축 값으로 입력되고, x축 값은 자동으로 0~1씩 증가하는 정수로 입력된다.
plt.show()

# %% [markdown]
# ##두번째 그래프

# %%
#가로축과 세로축의 [1,2,3,4], [12, 43, 25,15] 값을 가진 그래프를 그리는 코드를 작성하시오.

import matplotlib.pyplot as plt
plt.plot([1,2,3,4], [12,43,25,15])
plt.show()

# %% [markdown]
# #3️⃣ 그래프에 옵션 추가하기
#
# * 제목, 레이블과 같은 기본적인 옵션 추가가 가능하다.4️⃣

# %% [markdown]
# ##🎨그래프에 제목 넣기
#
# 📌title()함수
#
# ```
# plot.title('제목에 넣을 문자열')
# ```

# %%
#아래 코드를 실행하세요.
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')

plt.title('점찍기(plotting)')
plt.plot([10, 20, 30, 40])
plt.show()

# %%
#한글폰트 설치
#그대로 실행하기
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 2 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# ...

# %%
# !pip install koreanize-matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 72.0 MB/s eta 0:00:00
# ...

# %%
#아래 코드를 실행하세요.
import matplotlib.pyplot as plt
import koreanize_matplotlib

plt.title('직선')
plt.plot([10, 20, 30, 40])
plt.show()

# %% [markdown]
# ##🎨그래프에 범례 넣기
# * 그래프가 _____하는 바를 구별할 수 있도록 표시해놓는 ______
# * 범례는 보통 두 개 이상의 데이터를 표시할 때 사용합니다.
#
# 📌label 속성의 레이블 값으로 원하는 문자열을 넣어주고,
# 그래프를 그리기 전에 legend()함수를 실행시키면 레이블 값이 범례로 나타난다.
#
# *두 가지 범례를 넣으려면 plot함수를 2개 사용한다.

# %%
#범례를 표시하는 코드를 작성하세요.

import matplotlib.pyplot as plt
import koreanize_matplotlib
plt.title('plotting')

plt.plot([10,20,30,40], label= 'asc')  #증가를 뜻하는 asc범례
plt.plot([40,30,20,10], label = 'desc') #감소를 뜻하는 desc 범례
plt.legend()

plt.show()

# %% [markdown]
# 📌범례 위치 직접 지정하기
#
# 범례의 위치는 자동으로 결정되지만, 직접 지정도 가능하다.
# legend()함수 안의 loc이라는 속성에 값을 넣어주면 된다.
# *loc의 값은 0~10까지 넣을 수 있다.
#
# ```
# plt.legend(loc = 5)
# ```

# %%
#범례 위치 아래쪽으로 지정하는 코드를 작성하시오.
import matplotlib.pyplot as plt
import koreanize_matplotlib
plt.title('plotting')

plt.plot([10,20,30,40], label = 'asc')  #증가를 뜻하는 asc범례
plt.plot([40,30,20,10], label = 'desc') #감소를 뜻하는 desc 범례
plt.legend(loc =  10)

plt.show()

# %% [markdown]
# ##🎨그래프 색상 바꾸기
# * 원하는 색상으로 바꾸기 위해 color 속성 추가하면 된다.
# * color속성을 생략하면 자동으로 색상이 설정된다.

# %%
#그래프 색상 바꾸기
import matplotlib.pyplot as plt
import koreanize_matplotlib
plt.title('color') #제목 설정

plt.plot([10,20,30,40], color ='skyblue', label = 'skyblue')  #color( )함수 지정
plt.plot([40,30,20,10], 'pink', label = 'pink')    #색상만
plt.legend()  #범례 표시
plt.show()

# %%
#원하는 색상을 활용하여 각각 [10,20,30,40] [40,30,20,10]리스트를 그래프로 출력하는 코드를 작성하세요.

#그래프 색상 바꾸기
import matplotlib.pyplot as plt
plt.title('color') #제목 설정

plt.plot([10,20,30,40], color ='yellow', label = 'yellow')  #color( )함수 지정
plt.plot([40,30,20,10], 'cyan', label = 'cyan')    #색상만
plt.legend()  #범례 표시
plt.show()

# %% [markdown]
# ##🎨그래프 선 모양 바꾸기
# *plot()함수는 기본적으로 직선으로 그래프를 그린다.
#
# ```
# linestyle 속성에 원하는 선 모양 지정
# ```
# 📌색과 선모양을 '<색상><선모양>'을 동시에 적는 형태로 코드 작성도 가능
#
# ```
# plt.plot([1,2,3,4], 'r--')
# ```

# %%
import matplotlib.pyplot as plt

plt.title('linestyle')
plt.plot([10,20,30,40], 'y-', label='solid')   #빨간색 대시 그래프
plt.plot([40,30,20,10], 'c-.', label='dashdotted') #초록색 땡땡이 그래프
plt.legend()
plt.show()

# %% [markdown]
# ##🎨마커 모양 바꾸기
#
# * 마커모양 : 선, 점(.), 동그라미, 삼각형(^), 별
#
# 📌색상, 선모양, 마커모양 동시에 설정하기
#  '<색상><마커모양><선모양>'순으로 코드 작성
#
# ```
# plt.plot([1,2,3,4], 'r.--')
# ```

# %%
import matplotlib.pyplot as plt

plt.title('marker')
plt.plot([10,20,30,40], marker = 'x', label='circle') #빨간색 원형 마커
plt.plot([40,30,20,10],  'g^--', label='triangle up') #초록색 삼각형 마커
plt.legend()
plt.show()

# %% [markdown]
# #4️⃣ 내 생일의 기온변화 그래프로 그리기

# %% [markdown]
# ##1)데이터에 질문하기

# %% [markdown]
# ### ▶데이터 읽어오기

# %%
import csv

f = open('seoul.csv', encoding = "euc-kr")
data = csv.reader(f)

for row in data:
  print(row)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# ['2005-05-11', '108', '13.7', '12.1', '16.1']
# ['2005-05-12', '108', '14.1', '11.6', '19.6']
# ['2005-05-13', '108', '16.6', '10.1', '23.3']
# ['2005-05-14', '108', '16.7', '13.3', '20.7']
# ['2005-05-15', '108', '18.6', '12.5', '25.7']
# ['2005-05-16', '108', '19.6', '14.3', '25.3']
# ['2005-05-17', '108', '19.4', '16', '23.6']
# ['2005-05-18', '108', '15.4', '11.8', '19.6']
# ['2005-05-19', '108', '17.2', '11.8', '23']
# ['2005-05-20', '108', '18.5', '12.8', '24.5']
# ['2005-05-21', '108', '17.7', '13.6', '22.8']
# ['2005-05-22', '108', '15.9', '14.6', '18.5']
# ['2005-05-23', '108', '16.1', '13.1', '20.1']
# ['2005-05-24', '108', '17.6', '12.3', '23.5']
# ['2005-05-25', '108', '18.5', '12.6', '24']
# ['2005-05-26', '108', '19.3', '15.3', '25']
# ['2005-05-27', '108', '20.7', '14.6', '27.7']
# ['2005-05-28', '108', '22', '15.8', '28.2']
# ['2005-05-29', '108', '23.7', '17.1', '30.2']
# ['2005-05-30', '108', '21.5', '18', '26.7']
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#최고 기온데이터만 출력하기
import csv
f = open('seoul.csv', encoding="euc-kr")
data = csv.reader(f)
next(data)

for row in data :
  print(row[-1])
# Out:
# 20.7
# 22
# 21.3
# 22
# 25.4
# 21.3
# 16.1
# 14.9
# 21.1
# 24.1
# 20.4
# 17.4
# 21.3
# 20.6
# 20.9
# 20.2
# 21.6
# 20.9
# 21.3
# 22.7
# 19.9
# 19.6
# 16.3
# 17.1
# 18.7
# 18.2
# 20.7
# 19.6
# 20
# 20.1
# 20.3
# 21.3
# 21.1
# 11.1
# 13.6
# 17
# 18.1
# 12.4
# 9.4
# 11.9
# 13.2
# 13.4
# 14.9
# 16.4
# 15.2
# 17.6
# 12.6
# 11.7
# 6.7
# 4.3
# 7.1
# 6.2
# 11.2
# 9.9
# 5.9
# -0.7
# 1.5
# 1.9
# 2
# 2.9
# -2.4
# 1.4
# 3.4
# 6.1
# 1.3
# 2.6
# 5.8
# 1.9
# 6.6
# 8.1
# 4.3
# 0.6
# 3.8
# 9
# 6.4
# -5.1
# -2.4
# -2.1
# -0.4
# -0.2
# 1.9
# -8.1
# -10.2
# -9.4
# 0.9
# 6.8
# 6.4
# -0.7
# -1.9
# -4.4
# -6.1
# -2.1
# -1.3
# -3
# -2.9
# -1.7
# -0.1
# 2.9
# -1.2
# -0.9
# 2
# 3.3
# 4.8
# 4.5
# 4.7
# 0.1
# 0.9
# -4.5
# -3.6
# 2.8
# 2.8
# 2.3
# -6.1
# -5.1
# -2.7
# 0.1
# 0.3
# -0.6
# 0
# -1.3
# 0.8
# 0.8
# 6.2
# 1.6
# -0.2
# -5.4
# -4.1
# -5.5
# -5.7
# -3.7
# 1.3
# -4.1
# -2.5
# -2.8
# -1.2
# 1.3
# 2.3
# 2
# -1.4
# -1.6
# 0.3
# 5.5
# 7.3
# 5.1
# 5.4
# 2.7
# 1.7
# 0.8
# 4.1
# 8.4
# 6.3
# 5.6
# 4
# 0.1
# 4.9
# ...

# %% [markdown]
# ### ▶데이터를 리스트에 저장하기

# %%
#데이터를 리스트에 저장하기
#최고 기온 데이터를 날짜 순으로 저장하고자 result라는 리스트 생성
#최고 기온데이터가 존재하는 날의 최고 기온 데이터를 result 변수에 저장

import csv
import matplotlib.pyplot as plt

f = open('seoul.csv', encoding="euc-kr")
data = csv.reader(f)
next(data)
result = [] #최고 기온 데이터를 저장할 리스트 생성

for row in data:
  if row[-1] !='':  #최고 기온 데이터 값이 존재한다면 result리스트에 최고 기온 값 추가
    result.append(float(row[-1]))
print(result)
# Out:
# [20.7, 22.0, 21.3, 22.0, 25.4, 21.3, 16.1, 14.9, 21.1, 24.1, 20.4, 17.4, 21.3, 20.6, 20.9, 20.2, 21.6, 20.9, 21.3, 22.7, 19.9, 19.6, 16.3, 17.1, 18.7, 18.2, 20.7, 19.6, 20.0, 20.1, 20.3, 21.3, 21.1, 11.1, 13.6, 17.0, 18.1, 12.4, 9.4, 11.9, 13.2, 13.4, 14.9, 16.4, 15.2, 17.6, 12.6, 11.7, 6.7, 4.3, 7.1, 6.2, 11.2, 9.9, 5.9, -0.7, 1.5, 1.9, 2.0, 2.9, -2.4, 1.4, 3.4, 6.1, 1.3, 2.6, 5.8, 1.9, 6.6, 8.1, 4.3, 0.6, 3.8, 9.0, 6.4, -5.1, -2.4, -2.1, -0.4, -0.2, 1.9, -8.1, -10.2, -9.4, 0.9, 6.8, 6.4, -0.7, -1.9, -4.4, -6.1, -2.1, -1.3, -3.0, -2.9, -1.7, -0.1, 2.9, -1.2, -0.9, 2.0, 3.3, 4.8, 4.5, 4.7, 0.1, 0.9, -4.5, -3.6, 2.8, 2.8, 2.3, -6.1, -5.1, -2.7, 0.1, 0.3, -0.6, 0.0, -1.3, 0.8, 0.8, 6.2, 1.6, -0.2, -5.4, -4.1, -5.5, -5.7, -3.7, 1.3, -4.1, -2.5, -2.8, -1.2, 1.3, 2.3, 2.0, -1.4, -1.6, 0.3, 5.5, 7.3, 5.1, 5.4, 2.7, 1.7, 0.8, 4.1, 8.4, 6.3, 5.6, 4.0, 0.1, 4.9, 4.0, 7.9, 7.9, 2.2, 1.9, 1.5, 1.5, 1.8, 2.6, 3.8, 6.7, 11.8, 13.5, 15.7, 10.7, 7.9, 4.3, 6.0, 12.5, 17.0, 14.7, 11.4, 7.4, 8.0, 15.5
# ...

# %%
#len함수로 데이터 개수 확인하기
print(len(result))
# Out:
# 39463

# %% [markdown]
# ##2)데이터 시각화하기

# %%
#최고 기온 데이터를 모두 꺾은 선 그래프로 표현한 것
import matplotlib.pyplot as plt
plt.plot(result, 'r')   #result 리스트에 저장된 값을 빨간색 그래프로 그리기
plt.show()  #그래프 나타내기

# %%
#최고 기온 데이터를 모두 꺾은 선 그래프로 표현한 것
import matplotlib.pyplot as plt
plt.figure(figsize = (10,2), dpi = 300) #그래프 크기 조절
plt.plot(result, 'r')   #result 리스트에 저장된 값을 빨간색 그래프로 그리기
plt.show()  #그래프 나타내기

# %% [markdown]
# ##3)날짜 데이터 추출하기

# %% [markdown]
# ##🔎split()함수
# * 사용자가 설정하는 특정 문자를 기준으로 문자열 분리하는 명령어
#
#
# ```
# s = 'hello python'
# print(s.split())
# ```

# %%
#split함수를 이용하여 사용자가 설정하는 특정 문자를 기준으로 문자열 분리
s = 'hello python'
print(s.split())
# Out:
# ['hello', 'python']

# %%
#날짜 1907-10-01을 - 기준으로 분리하기
date ="1907-10-01"
date.split('-')
# Out:
# ['1907', '10', '01']

# %%
print(date.split('-')[0])  #1번째 데이터가 의미하는 것은? 년도
print(date.split('-')[1])  #2번째 데이터가 의미하는 것은? 월
print(date.split('-')[2])  #3번째 데이터가 의미하는 것은? 일
# Out:
# 1907
# 10
# 01

# %%
#1년중 여름의 정점인 8월의 최고 기온 데이터만 추출해서 그래프로 그리기

import csv
import matplotlib.pyplot as plt

f= open('seoul.csv', encoding="euc-kr")
data = csv.reader(f)
next(data)
result = []

for row in data :
    if row[-1] != '' :                      #최고 기온 값이 존재한다면
        if row[0].split('-')[1] == '08' :    #8월에 해당하는 값이라면
            result.append(float(row[-1]))    #result 리스트에 최고 기온 값 추가

plt.plot(result, 'hotpink')         #result 리스트에 저장된 값을 hotpink색으로 그리기
plt.show()                           #그래프 나타내기

# %% [markdown]
# ###✨다양한 색상 사용하기
# matplotlib 함수 안내: http://bit.ly/2U5toVX

# %%
#2월 14일의 날짜 기온데이터를 추출하는 코드
for row in data:
  if row[-1] != '':
    if row[0].split('-')[1] == '02' and row[0].split('-')[2] =='14_':
      result.append(float(row[-1]))

# %%
#매년 돌아오는 생일을 기준으로 그래프 그려보기
#매년 2월 14일 최고 기온 데이터를 추출하여 그래프로 나타내기

import csv
import matplotlib.pyplot as plt

f = open('seoul.csv')
data = csv.reader(f)
next(data)
result = []

for row in data:
  if row[-1] != '':
    if ______________________________ and ______________________________:
      result.append(float(row[-1]))

plt.plot(_____, '__________')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /tmp/ipykernel_2414/3875221462.py in <cell line: 0>()
#       7 f = open('seoul.csv')
#       8 data = csv.reader(f)
# ----> 9 next(data)
#      10 result = []
#      11
#
# /usr/lib/python3.12/codecs.py in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xb3 in position 0: invalid start byte

# %%
import csv
import matplotlib.pyplot as plt

f = open('seoul.csv', encoding='cp949')
data = csv.reader(f)
next(data)
high = []
low = []

for row in data :
  if row[-1] != '' and  row[-2] != '':                                                     #최고기온과 최저기온 값이 존재한다면
    date = row[0].split('-')                                                     #날짜 값을 -문자를 기준으로 구분하여 저장
    if 1983 <= int(date[0]):
      if date[1] == '02' and date[2] == '14':
        high.append(float(row[-1]))                                                 #최고 기온값을 high리스트에 저장
        low.append(float(row[-2]))                                                 #최저 기온값을 low리스트에 저장

plt.rc('font', family = 'NanumBarunGothic')
plt.rcParams['axes.unicode_minus'] = False                                          #마이너스 기호 깨짐 방지
plt.________('__________________________________')                                  #제목 설정
plt.plot(________, 'hotpink', ________ ='high')                                            #핫핑크 색 설정, 레이블 표시
plt.plot(________, 'skyblue', ________ ='low')                                              #하늘색 설정, 레이블 표시
plt.________()                                                                       #범례 표시
plt.________()                                                                          #그래프 나타내기

# %% [markdown]
# #5️⃣기온데이터를 다양하게 시각화하기

# %% [markdown]
# ##1)히스토그램

# %%
import matplotlib.pyplot as plt
plt.hist([1,1,2,3,4,5,6,6,7,8,10]) #히스토그램을 그리는 코드
plt.show()

#1과 6에 해당하는 막대의 높이는 2 이고, 9에 해당하는 막대의 높이는 0, 나머지 숫자에 해당하는 막대의 높이는 1이다.

# %%
import random
print(random.randint(1,6))
# Out:
# 5

# %%
#random 함수를 이용한 주사위 5번 던지기 상황
import random
dice = []
for i in range(5):
  dice.append(random.randint(1,6))
print(dice)
# Out:
# [1, 3, 1, 5, 6]

# %%
#히스토그램으로 표현하기
import matplotlib.pyplot as plt
import random

dice = []
for i in range(5):
  dice.append(random.randint(1,6))

plt.hist(dice, bins = 6)                          #bins 옵션은 가로축의 구간 개수를 설정하는 속성
plt.show()

# %%
import matplotlib.pyplot as plt
import random

dice = []
for i in range(100):                        #100번동안 주사위를 굴린다.
  dice.append(random.randint(1,6))

plt.hist(dice, bins = 6)                          #bins 옵션은 가로축의 구간 개수를 설정하는 속성
plt.show()

# %% [markdown]
# ##2)기온데이터를 히스토그램으로 표현하기

# %%
#최고 기온데이터를 히스토그램으로 표현하기

import csv
import matplotlib.pyplot as plt

f = open('seoul.csv')
data = csv.reader(f)
next(data)
result = []

for row in data :
  if row[-1] !='':
    result.append(float(row[-1]))

plt.hist(result, bins=100, color = 'r')  #result의 결과를 100개의 가로축 구간 개수로 설정하여 히스토그램 그리기
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#8월 데이터만 히스토그램으로 표현하기
import csv
import matplotlib.pyplot as plt

f = open('seoul.csv')
data = csv.reader(f)
next(data)
aug = []

for row in data :
  month =row[0].split('-')[1]                                              #-로 구분된 값 중 2번째 값을 month에 저장
  if row[-1] !='':
    if month =='08':
      aug.append(float(row[-2]))

plt.hist(aug, bins=100, color = 'r')
plt.show()

# %%
#1월과 8월의 데이터를 히스토그램으로 시각화

import csv
import matplotlib.pyplot as plt

f = open('seoul.csv')
data = csv.reader(f)
next(data)
aug = []
jan =[]

for row in data :
  month =row[0].split('-')[1]     #-로 구분된 값 중 2번째 값을 month에 저장
  if row[-2] !='':
    if month =='08':                 #8월이면
      aug.append(float(row[-1]))
    if month =='01':                 #1월이면
      jan.append(float(row[-1]))

plt.hist(aug, bins=100, color = 'r', label = 'aug')        #8월 데이터를 히스토그램으로 출력, 색상은 빨간색, 레이블은 aug로 설정한다.
plt.hist(jan, bins=100, color = 'b', label = 'jan')        #1월 데이터를 히스토그램으로 출력, 색상은 파란색, 레이블은 jan로 설정한다.
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ##3)기온데이터를 상자 그림으로 표현하기
#
# * 상자그림은 가공하지 않은 데이터를 그대로 이용하는 것이 아니라, 자료에서 얻어낸 ,최댓값, 최솟값, 상위 1/4, 중앙, 3/4에 위치한 값을 보여주는 그래프

# %%
import random
import matplotlib.pyplot as plt

result = []
for i in range(13):                          #13번 반복
  result.append(random.randint(1,1000))     #1~1000개의 값을 임의로 추출하여 추가하기
print(sorted(result))

plt.boxplot(result)   #상자그림으로 출력하기
plt.show()
# Out:
# [93, 132, 252, 257, 372, 475, 523, 703, 794, 863, 871, 898, 959]

# %%
#정확한 위치 값이 알고 싶다면? percentile( )함수 사용하기!

import numpy as np
result = np.array(result)
print("1/4 : " +str(np.percentile(result,25)))
print("2/4 : " +str(np.percentile(result,50)))
print("3/4 : " +str(np.percentile(result,75)))
# Out:
# 1/4 : 257.0
# 2/4 : 523.0
# 3/4 : 863.0

# %%
#서울의 최고 기온데이터를 상자그림으로 그리기

import csv
import matplotlib.pyplot as plt

f = open('seoul.csv')
data = csv.reader(f)
next(data)
result = []

for row in data :
  if row[-1] !='':
    result.append(float(row[-1]))   #서울의 최고기온값을 실수형태로 변환

plt.boxplot(result)                   #결과값을 상자그림으로 표현
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import numpy as np
result = np.array(result)
print("1/4 : " +str(np.percentile(result,25)))
print("2/4 : " +str(np.percentile(result,50)))
print("3/4 : " +str(np.percentile(result,75)))
# Out:
# 1/4 : 7.2
# 2/4 : 18.6
# 3/4 : 26.2

# %%
#1월과 8월의 데이터를 상자 그림으로 시각화

import csv
import matplotlib.pyplot as plt

f = open('seoul.csv')
data = csv.reader(f)
next(data)
aug = []
jan =[]

for row in data :
  month =row[0].split('-')[1] #-로 구분된 값 중 2번째 값을 month에 저장
  if row[-1] !='':
    if month =='08':
      aug.append(float(row[-1]))               #8월의 최고기온값을 실수형태로 변환 예)'20.1' -> 20.1
    if month =='01':
      jan.append(float(row[-1]))               #1월의 최고기온값을 실수형태로 변환 예)'6.7' -> 6.7

plt.boxplot(aug)                #8월의 데이터를 상자그림으로 표현하기
plt.boxplot(jan)                #1월의 데이터를 상자그림으로 표현하기

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#1월과 8월의 데이터를 상자 그림으로 시각화

import csv
import matplotlib.pyplot as plt

f = open('seoul.csv', encoding = 'cp949')
data = csv.reader(f)
next(data)
aug = []
jan =[]

for row in data :
  month =row[0].split('-')[1] #-로 구분된 값 중 2번째 값을 month에 저장
  if row[-1] !='':
    if month =='______':
      aug.append(float(row[-1]))
    if month =='______':
      jan.append(float(row[-1]))

plt.boxplot([______,______])       #하나의 상자그림에 1월, 8월 데이터를 동시에 출력하기
plt.show()

# %%
#데이터를 월별로 분류해 저장하기

import csv
import matplotlib.pyplot as plt

f = open('seoul.csv', encoding = 'cp949')
data = csv.reader(f)
next(data)

#월별 데이터를 저장할 리스트 month생성(12개)
month = [ ___,___, ___,___ ,___,___, ___,___, ___,___ ,___,___ ]

#월과 같은 번호의 인덱스에 월별 데이터 저장(예:1월 -> month[0])
for row in data :
    if row[-1] !='':
      month[int(row[0].split('-')[1])-1].append(float(row[-1]))

plt.______(______) #상자모양으로 출력하기
plt.show()

# %%
#8월 일별 기온데이터를 상자 그림으로 표현하기

import csv
import matplotlib.pyplot as plt

f = open('seoul.csv')
data = csv.reader(f)
next(data)

day = []                                                                  #일별데이터 리스트 생성
for i in range(31):
  day.append([])                                                         #day리스트 내 31개 리스트 추가하기

for row in data :
    if row[-1] !='':
      if row[0].split('-')[1] =="08" :                                    #8월이라면
        day[int(row[0].split('-')[2])-1].append(float(row[-1]))           #최고 기온 값 저장

plt.style.use('ggplot')                                                   #그래프 스타일 지정
plt.figure(figsize=(10,5), dpi = 300)                                     #그래프 크기 수정
plt.boxplot(day, showfliers=False)                                #아웃라이어 값 생략
plt.show()
